# %% [markdown]
# ## Прогноз виручки (three-phase linear)
#
# Зошит повторює ключові кроки `3p_linear_model`: базовий Holt-Winters, сезонні та лагові ознаки, фінальна модель XGBoost для кожної товарної групи.

# %%
from pathlib import Path

import numpy as np
import pandas as pd

from three_phase_linear import ForecastConfig, run_three_phase_forecast

DATA_PATH = Path('forecast_revenue_dataset.csv')
OUTPUT_PATH = Path('money_three_phase_forecast.csv')
GROUP_COLS = ['category_id']
TARGET_COLUMN = 'revenue'
REGRESSORS = ['is_sale_prohibition', 'cos_month', 'sin_month', 'cos_quarter', 'sin_quarter', 'unique_brand_count']
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[1], line 6
#       3 import numpy as np
#       4 import pandas as pd
# ----> 6 from three_phase_linear import ForecastConfig, run_three_phase_forecast
#       8 DATA_PATH = Path('forecast_revenue_dataset.csv')
#       9 OUTPUT_PATH = Path('money_three_phase_forecast.csv')
#
# File ~/Desktop/repository_matviyenkos/three_phase_linear.py:31
#      27 from sklearn.model_selection import TimeSeriesSplit
#      29 from statsmodels.tsa.holtwinters import ExponentialSmoothing
# ---> 31 import xgboost as xgb
#      34 logger = logging.getLogger(__name__)
#      35 if not logger.handlers:
#
# File ~/Desktop/repository_matviyenkos/.venv/lib/python3.9/site-packages/xgboost/__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import tracker  # noqa
#       7 from . import collective, dask
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)
#      15     build_info,
#      16 )
#
# File ~/Desktop/repository_matviyenkos/.venv/lib/python3.9/site-packages/xgboost/tracker.py:9
#       6 from enum import IntEnum, unique
#       7 from typing import Dict, Optional, Union
# ----> 9 from .core import _LIB, _check_call, make_jcargs
#      12 def get_family(addr: str) -> int:
#      13     """Get network family from address."""
#
# File ~/Desktop/repository_matviyenkos/.venv/lib/python3.9/site-packages/xgboost/core.py:269
#     265     return lib
#     268 # load the XGBoost library globally
# --> 269 _LIB = _load_lib()
#     272 def _check_call(ret: int) -> None:
#     273     """Check the return value of C API call
#     274
#     275     This function will raise exception when error occurs.
#    (...)
#     281         return value from API calls
#     282     """
#
# File ~/Desktop/repository_matviyenkos/.venv/lib/python3.9/site-packages/xgboost/core.py:222, in _load_lib()
#     220     if not lib_success:
#     221         libname = os.path.basename(lib_paths[0])
# --> 222         raise XGBoostError(
#     223             f"""
#     224 XGBoost Library ({libname}) could not be loaded.
#     225 Likely causes:
#     226   * OpenMP runtime is not installed
#     227     - vcomp140.dll or libgomp-1.dll for Windows
#     228     - libomp.dylib for Mac OSX
#     229     - libgomp.so for Linux and other UNIX-like OSes
#     230     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#     231
#     232   * You are running 32-bit Python on a 64-bit OS
#     233
#     234 Error message(s): {os_error_list}
#     235 """
#     236         )
#     237     _register_log_callback(lib)
#     239     def parse(ver: str) -> Tuple[int, int, int]:
#
# XGBoostError:
# XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed
#     - vcomp140.dll or libgomp-1.dll for Windows
#     - libomp.dylib for Mac OSX
#     - libgomp.so for Linux and other UNIX-like OSes
#     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#
#   * You are running 32-bit Python on a 64-bit OS
#
# Error message(s): ["dlopen(/Users/sonyamatviyenko/Desktop/repository_matviyenkos/.venv/lib/python3.9/site-packages/xgboost/lib/libxgboost.dylib, 0x0006): Library not loaded: @rpath/libomp.dylib\n  Referenced from: <89AD948E-E564-3266-867D-7AF89D6488F0> /Users/sonyamatviyenko/Desktop/repository_matviyenkos/.venv/lib/python3.9/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: tried: '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file)"]

# %%
import sys
print(sys.executable)

!"{sys.executable}" -m pip install numpy pandas matplotlib seaborn scikit-learn xgboost prophet
# Out:
# /Library/Developer/CommandLineTools/usr/bin/python3
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 3.5 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-2.3.3-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 3.0 MB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 5.1 MB/s eta 0:00:01
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 1.0 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 657 kB/s eta 0:00:01
# Collecting xgboost
#   Downloading xgboost-2.1.4-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 2.0 MB/s eta 0:00:01
# Collecting prophet
#   Downloading prophet-1.2.1-py3-none-macosx_11_0_arm64.whl (12.1 MB)
#      |████████████████████████████████| 12.1 MB 1.8 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 826 kB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      |████████████████████████████████| 347 kB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 929 kB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from matplotlib) (25.0)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.8 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 1.1 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 1.8 MB/s eta 0:00:01
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp39-cp39-macosx_11_0_arm64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 3.2 MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 1.2 MB/s eta 0:00:01
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 5.7 MB/s eta 0:00:01
# Collecting holidays<1,>=0.25
#   Downloading holidays-0.83-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 1.6 MB/s eta 0:00:01
# Collecting tqdm>=4.36.1
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 1.0 MB/s eta 0:00:01
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 1.2 MB/s eta 0:00:01
# Collecting stanio<2.0.0,>=0.4.0
#   Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Installing collected packages: tzdata, pytz, numpy, tqdm, stanio, pyparsing, pillow, pandas, kiwisolver, importlib-resources, fonttools, cycler, contourpy, threadpoolctl, scipy, matplotlib, joblib, holidays, cmdstanpy, xgboost, seaborn, scikit-learn, prophet
# Successfully installed cmdstanpy-1.3.0 contourpy-1.3.0 cycler-0.12.1 fonttools-4.60.1 holidays-0.83 importlib-resources-6.5.2 joblib-1.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 numpy-2.0.2 pandas-2.3.3 pillow-11.3.0 prophet-1.2.1 pyparsing-3.2.5 pytz-2025.2 scikit-learn-1.6.1 scipy-1.13.1 seaborn-0.13.2 stanio-0.5.1 threadpoolctl-3.6.0 tqdm-4.67.1 tzdata-2025.2 xgboost-2.1.4
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import sys
print(sys.executable)
# Out:
# /Library/Developer/CommandLineTools/usr/bin/python3

# %%
# !{sys.executable} -m pip install numpy pandas matplotlib seaborn scikit-learn xgboost prophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (2.0.2)
# Requirement already satisfied: pandas in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: seaborn in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: xgboost in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (2.1.4)
# Requirement already satisfied: prophet in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (1.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: packaging>=20.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: cycler>=0.10 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from prophet) (1.3.0)
# Requirement already satisfied: holidays<1,>=0.25 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from prophet) (0.83)
# Requirement already satisfied: tqdm>=4.36.1 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from prophet) (4.67.1)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/sonyamatviyenko/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
df = pd.read_csv(DATA_PATH, sep=';')
df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df = df.sort_values(GROUP_COLS + ['date']).reset_index(drop=True)
for col in REGRESSORS:
    df[col] = pd.to_numeric(df[col], errors='coerce')

agg_df = df.groupby(['date', 'category_id', 'category_title'], as_index=False).agg(
    revenue_sum=('revenue', 'sum'),
    revenue_count=('revenue', 'count'),
    is_sale_prohibition=('is_sale_prohibition', 'max'),
    cos_month=('cos_month', 'mean'),
    sin_month=('sin_month', 'mean'),
    cos_quarter=('cos_quarter', 'mean'),
    sin_quarter=('sin_quarter', 'mean'),
    unique_brand_count=('unique_brand_count', 'mean'),
)
agg_df.loc[agg_df['revenue_count'] == 0, 'revenue_sum'] = np.nan
df = agg_df.rename(columns={'revenue_sum': 'revenue'}).drop(columns=['revenue_count'])
df = df.sort_values(GROUP_COLS + ['date']).reset_index(drop=True)

future_counts = df[df[TARGET_COLUMN].isna()].groupby(GROUP_COLS).size()
forecast_horizon = int(future_counts.max()) if not future_counts.empty else 12
if forecast_horizon <= 0:
    forecast_horizon = 12

print(f'Горизонт прогнозу: {forecast_horizon} періодів')

# %%
input_cols = ['date', *GROUP_COLS, TARGET_COLUMN, *REGRESSORS]
input_cols = list(dict.fromkeys(input_cols))
config = ForecastConfig(
    time_col='date',
    target_col=TARGET_COLUMN,
    group_cols=GROUP_COLS,
    freq='MS',
    forecast_horizon=forecast_horizon,
    seasonal_periods=12,
    min_history=24,
    lags=(1, 2, 3, 6, 12, 18, 24),
    rolling_windows=(3, 6, 12, 24),
    additional_regressors=REGRESSORS,
    random_search_iterations=10,
    n_splits=4,
    random_state=46,
)

preds, summaries = run_three_phase_forecast(df[input_cols].copy(), config)
preds = preds.rename(columns={
    'prediction': 'revenue_forecast',
    f'{TARGET_COLUMN}_holtwinters': 'revenue_baseline',
})
summary_report = pd.DataFrame({
    'group_key': [s.group_key[0] for s in summaries],
    'train_rows': [s.train_rows for s in summaries],
    'cv_mae': [s.best_score for s in summaries],
    'skipped_reason': [s.skipped_reason for s in summaries],
})
summary_report.head()

# %%
merge_cols = [*GROUP_COLS, 'date']
result_df = df.copy()
result_df['is_forecast_period'] = result_df[TARGET_COLUMN].isna()
result_df = result_df.merge(preds[merge_cols + ['revenue_forecast']], on=merge_cols, how='left')
result_df['revenue'] = result_df['revenue'].astype(float)
result_df['revenue'] = result_df['revenue'].fillna(result_df['revenue_forecast'])

output_columns = ['date', 'category_id', 'category_title', 'revenue']
final_output = result_df.loc[result_df['is_forecast_period'], output_columns]
final_output = final_output.groupby(['date', 'category_id', 'category_title'], as_index=False)['revenue'].sum()
final_output = final_output.sort_values(['category_id', 'date']).reset_index(drop=True)
final_output.to_csv(OUTPUT_PATH, index=False)

final_output.tail()

# %%
summary_report
